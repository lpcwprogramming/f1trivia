# %% [markdown]
# # Import Dependencies

# %%
import pandas as pd
import csv
import os

# %% [markdown]
# # Read CSV files

# %%
#Races dataset
races_csv = "Resources/Data/archive/races.csv"
races_df = pd.read_csv(races_csv)

races = races_df[["raceId", "year", "round", "circuitId", "name", "date"]]

# %%
#Results dataset
results_csv = "Resources/Data/archive/results.csv"
results_df = pd.read_csv(results_csv)
results_rename = results_df.rename(columns={"points":"RacePoints"})
results = results_rename[["resultId","raceId","driverId","number","positionOrder","RacePoints","laps"]]

# %%
#Drivers dataset
drivers_csv = "Resources/Data/archive/drivers.csv"
drivers_df = pd.read_csv(drivers_csv)

drivers = drivers_df[["driverId","driverRef","code","forename","surname","nationality"]]

# %%
surname = drivers.sort_values(by="driverId")

sur = surname.drop_duplicates(subset=["driverId"], keep="first").set_index("surname").sort_index()

pd.set_option('display.max_rows',1000)

sur
# Out:
#                          driverId           driverRef code           forename  \
# surname
# Abate                         446               abate   \N              Carlo
# Abecassis                     725           abecassis   \N             George
# Acheson                       186             acheson   \N              Kenny
# Adams                         113               adams   \N           Philippe
# Ader                          796                ader   \N               Walt
# Adolff                        714              adolff   \N               Kurt
# Agabashian                    615          agabashian   \N               Fred
# Ahrens                        379              ahrens   \N               Kurt
# Aitken                        851              aitken  AIT               Jack
# Albers                         27              albers  ALB         Christijan
# Albon                         848               albon  ALB          Alexander
# Alboreto                      105            alboreto   \N            Michele
# Alesi                          55               alesi   \N               Jean
# Alguersuari                   153         alguersuari  ALG              Jaime
# Alliot                        112              alliot   \N           Philippe
# Allison                       477             allison   \N              Cliff
# Alonso                          4              alonso  ALO           Fernando
# Amati                         132               amati   \N           Giovanna
# Amick                         591        george_amick   \N             George
# Amick                         517               amick   \N                Red
# Amon                          278                amon   \N              Chris
# Anderson                      383            anderson   \N                Bob
# Andersson                     260           andersson   \N              Conny
# Andretti                      121            andretti   \N            Michael
# Andretti                      207      mario_andretti   \N              Mario
# Andrews                       631             andrews   \N              Keith
# Apicella                      124            apicella   \N              Marco
# Armi                          676                armi   \N              Frank
# Arnold                        557              arnold   \N              Chuck
# Arnoux                        163              arnoux   \N               René
# Arundell                      397            arundell   \N              Peter
# Ascari                        647              ascari   \N            Alberto
# Ashdown                       569             ashdown   \N              Peter
# Ashley                        270              ashley   \N                Ian
# Ashmore                       460             ashmore   \N              Gerry
# Aston                         749               aston   \N               Bill
# Attwood                       370             attwood   \N            Richard
# Ayulo                         675               ayulo   \N              Manny
# Badoer                         69              badoer  BAD               Luca
# Baghetti                      394            baghetti   \N          Giancarlo
# Bailey                        141              bailey   \N             Julian
# Baldi                         184               baldi   \N              Mauro
# Ball                          734                ball   \N              Bobby
# Balsa                         754               balsa   \N             Marcel
# Bandini                       385             bandini   \N            Lorenzo
# Banks                         731               banks   \N              Henry
# Barbazza                      120            barbazza   \N           Fabrizio
# Barber                        342              barber   \N               Skip
# Barber                        696         john_barber   \N               John
# Barilla                       147             barilla   \N              Paolo
# Barrichello                    22         barrichello  BAR             Rubens
# Bartels                       143             bartels   \N            Michael
# Barth                         431               barth   \N              Edgar
# Bassi                         426               bassi   \N            Giorgio
# Bauer                         716               bauer   \N              Erwin
# Baumgartner                    47         baumgartner   \N              Zsolt
# Bayol                         625               bayol   \N               Élie
# Beauman                       682             beauman   \N                Don
# Bechem                        715              bechem   \N            Günther
# Behra                         554               behra   \N               Jean
# Bell                          321                bell   \N              Derek
# Bellof                        185              bellof   \N             Stefan
# Belmondo                      108            belmondo   \N               Paul
# Belsø                         311               belso   \N                Tom
# Beltoise                      306            beltoise   \N        Jean-Pierre
# Beretta                       106             beretta   \N            Olivier
# Berg                          180                berg   \N              Allen
# Berger                        681      georges_berger   \N            Georges
# Berger                         77              berger   \N            Gerhard
# Bernard                       103             bernard   \N               Éric
# Bernoldi                       59            bernoldi   \N            Enrique
# Bertaggia                     134           bertaggia   \N             Enrico
# Bettenhausen                  529        bettenhausen   \N               Tony
# Beuttler                      329            beuttler   \N               Mike
# Bianchi                       376             bianchi  BIA             Lucien
# Bianchi                       824       jules_bianchi  BIA              Jules
# Bianco                        746              bianco   \N               Gino
# Binder                        246              binder   \N               Hans
# Biondetti                     791           biondetti   \N           Clemente
# Bira                          669                bira   \N             Prince
# Birger                        649              birger   \N              Pablo
# Bisch                         599               bisch   \N                Art
# Blanchard                     572           blanchard   \N              Harry
# Bleekemolen                   247         bleekemolen   \N            Michael
# Blignaut                      417            blignaut   \N               Alex
# Blokdyk                       409             blokdyk   \N             Trevor
# Blundell                       87            blundell   \N               Mark
# Boesel                        196              boesel   \N               Raul
# Boffa                         492               boffa   \N             Menato
# Bondurant                     396           bondurant   \N                Bob
# Bonetto                       697             bonetto   \N             Felice
# Bonnier                       347             bonnier   \N                 Jo
# Bonomi                        499              bonomi   \N            Roberto
# Bordeu                        485              bordeu   \N        Juan Manuel
# Borgudd                       201             borgudd   \N               Slim
# Botha                         384               botha   \N               Luki
# Bottas                        822              bottas  BOT           Valtteri
# Boullion                       96            boullion   \N    Jean-Christophe
# Bourdais                        7            bourdais  BOU          Sébastien
# Boutsen                       123             boutsen   \N            Thierry
# Boyd                          533                boyd   \N             Johnny
# Brabham                       150        gary_brabham   \N               Gary
# Brabham                       356        jack_brabham   \N               Jack
# Brabham                       101             brabham   \N              David
# Brack                         343               brack   \N               Bill
# Brambilla                     230           brambilla   \N           Vittorio
# Brambilla                     443   ernesto_brambilla   \N            Ernesto
# Branca                        780              branca   \N               Toni
# Brancatelli                   234         brancatelli   \N         Gianfranco
# Brandon                       688             brandon   \N               Eric
# Branson                       511             branson   \N                Don
# Bridger                       605             bridger   \N                Tom
# Brise                         294               brise   \N               Tony
# Bristow                       505             bristow   \N              Chris
# Broeker                       448             broeker   \N              Peter
# Brooks                        479              brooks   \N               Tony
# Brown                         286               brown   \N            Warwick
# Brown                         771          walt_brown   \N               Walt
# Brown                         689          alan_brown   \N               Alan
# Brudes                        750              brudes   \N              Adolf
# Brundle                        84             brundle   \N             Martin
# Bruni                          46               bruni   \N          Gianmaria
# Bryan                         525               bryan   \N              Jimmy
# Bucci                         645               bucci   \N             Clemar
# Bucknum                       405             bucknum   \N             Ronnie
# Bueb                          549                bueb   \N               Ivor
# Buemi                          67               buemi  BUE          Sébastien
# Bueno                         331               bueno   \N               Luiz
# Burgess                       437             burgess   \N                Ian
# Burti                          54               burti   \N            Luciano
# Bussinello                    424          bussinello   \N            Roberto
# Button                         18              button  BUT             Jenson
# Byrne                         210               byrne   \N              Tommy
# Cabantous                     704           cabantous   \N               Yves
# Cabianca                      543            cabianca   \N             Giulio
# Cabral                        432              cabral   \N    Mário de Araújo
# Cade                          576                cade   \N               Phil
# Caffi                         133               caffi   \N               Alex
# Campbell-Jones                436      campbell-jones   \N               John
# Campos                        167              campos   \N             Adrián
# Cannon                        355              Cannoc   \N               John
# Cantoni                       748             cantoni   \N              Eitel
# Cantrell                      803            cantrell   \N               Bill
# Capelli                       122             capelli   \N               Ivan
# Carini                        722              carini   \N              Piero
# Carter                        518              darter   \N              Duane
# Castellotti                   608         castellotti   \N            Eugenio
# Cecotto                       188             cecotto   \N             Johnny
# Cevert                        327              cevert   \N           François
# Chaboud                       774             chaboud   \N             Eugène
# Chamberlain                   463         chamberlain   \N                Jay
# Chandhok                      812            chandhok  CHA              Karun
# Chapman                       635             chapman   \N              Colin
# Charlton                      293            charlton   \N               Dave
# Chaves                        142              chaves   \N              Pedro
# Cheesbourg                    560          cheesbourg   \N               Bill
# Cheever                       158             cheever   \N              Eddie
# Chiesa                        130              chiesa   \N             Andrea
# Chilton                       820             chilton  CHI                Max
# Chimeri                       503             chimeri   \N             Ettore
# Chiron                        589              chiron   \N              Louis
# Chitwood                      794            chitwood   \N               Joie
# Christie                      516            christie   \N                Bob
# Claes                         660               claes   \N             Johnny
# Clapham                       416             clapham   \N              David
# Clark                         373               clark   \N                Jim
# Cogan                         214               cogan   \N              Kevin
# Collins                       581             collins   \N              Peter
# Collomb                       428             collomb   \N            Bernard
# Colombo                       244             colombo   \N            Alberto
# Comas                         100               comas   \N               Érik
# Comotti                       740             comotti   \N             Franco
# Connor                        726       george_connor   \N             George
# Constantine                   574         constantine   \N             George
# Cordts                        372              cordts   \N               John
# Coulthard                      14           coulthard  COU              David
# Courage                       361             courage   \N              Piers
# Craft                         354               craft   \N              Chris
# Crawford                      302            crawford   \N                Jim
# Crawford                      561        ray_crawford   \N                Ray
# Crespo                        761              crespo   \N            Alberto
# Creus                         504               creus   \N            Antonio
# Crockett                      674            crockett   \N              Larry
# Crook                         705               crook   \N               Tony
# Cross                         656               cross   \N                Art
# Crossley                      785            crossley   \N              Geoff
# Cruz                          698                cruz   \N             Adolfo
# Daigh                         507               daigh   \N              Chuck
# Dalmas                        114              dalmas   \N            Yannick
# Daly                          206                daly   \N              Derek
# Danner                        157              danner   \N          Christian
# Daponte                       672             daponte   \N              Jorge
# Davidson                       19            davidson  DAV            Anthony
# Davies                        653              davies   \N              Jimmy
# Davis                         462               davis   \N              Colin
# Daywalt                       556             daywalt   \N              Jimmy
# Depailler                     221           depailler   \N            Patrick
# Diniz                          64               diniz   \N              Pedro
# Dinsmore                      630            dinsmore   \N               Duke
# Dochnal                       451             dochnal   \N              Frank
# Dolhem                        319              dolhem   \N               José
# Donnelly                      151            donnelly   \N             Martin
# Donohue                       288             donohue   \N               Mark
# Doornbos                       38            doornbos  DOO             Robert
# Downing                       744             downing   \N                Ken
# Drake                         548               drake   \N                Bob
# Driver                        310              driver   \N              Paddy
# Drogo                         544               drogo   \N              Piero
# Duke                          490                duke   \N              Geoff
# Dumfries                      174            dumfries   \N             Johnny
# Duncan                        678              duncan   \N                Len
# Dusio                         760               dusio   \N              Piero
# Délétraz                       98            deletraz   \N         Jean-Denis
# Eaton                         352               eaton   \N             George
# Ecclestone                    587          ecclestone   \N             Bernie
# Edmunds                       614             edmunds   \N                Don
# Edwards                       265             edwards   \N                Guy
# Elford                        350              elford   \N                Vic
# Elisian                       596             elisian   \N                 Ed
# Emery                         585               emery   \N               Paul
# Enge                           61                enge   \N              Tomáš
# England                       621             england   \N               Paul
# Ericsson                      828            ericsson  ERI             Marcus
# Ertl                          229                ertl   \N             Harald
# Estéfano                      439            estefano   \N              Nasif
# Evans                         276               evans   \N                Bob
# Fabi                          190        corrado_fabi   \N            Corrado
# Fabi                          170                fabi   \N                Teo
# Fabre                         169               fabre   \N             Pascal
# Facetti                       325             facetti   \N              Carlo
# Fagioli                       786             fagioli   \N              Luigi
# Fairman                       486             fairman   \N               Jack
# Fangio                        579              fangio   \N               Juan
# Farina                        642              farina   \N               Nino
# Faulkner                      654            faulkner   \N               Walt
# Firman                         52              firman   \N              Ralph
# Fischer                       723             fischer   \N               Rudi
# Fisher                        392              fisher   \N               Mike
# Fisichella                     21          fisichella  FIS          Giancarlo
# Fitch                         667               fitch   \N               John
# Fittipaldi                    850   pietro_fittipaldi  FIT             Pietro
# Fittipaldi                    104          fittipaldi   \N          Christian
# Fittipaldi                    290   wilson_fittipaldi   \N             Wilson
# Fittipaldi                    224  emerson_fittipaldi   \N            Emerson
# Fitzau                        713              fitzau   \N               Theo
# Flaherty                      559            flaherty   \N                Pat
# Flinterman                    759          flinterman   \N                Jan
# Flockhart                     541           flockhart   \N                Ron
# Fohr                          795                fohr   \N              Myron
# Foitek                        148              foitek   \N             Gregor
# Follmer                       332             follmer   \N             George
# Fonder                        730              fonder   \N             George
# Fontana                        82             fontana   \N           Norberto
# Fontes                        568              fontes   \N           Azdrubal
# Forberg                       767             forberg   \N               Carl
# Force                         534               force   \N               Gene
# Forini                        171              forini   \N             Franco
# Fotheringham-Parker           777              parker   \N             Philip
# Foyt                          531                foyt   \N            Anthony
# Franchi                       248               gimax   \N              Carlo
# Francia                       220             francia   \N            Giorgio
# Freeland                      528            freeland   \N                Don
# Frentzen                       49            frentzen   \N       Heinz-Harald
# Friesacher                     40          friesacher  FRI            Patrick
# Fry                           788                 fry   \N                Joe
# Frère                         632               frere   \N               Paul
# Fushida                       299             fushida   \N            Hiroshi
# Gabbiani                      213            gabbiani   \N              Beppe
# Gachot                         92              gachot   \N           Bertrand
# Gaillard                      236            gaillard   \N            Patrick
# Galica                        242              galica   \N             Divina
# Galli                         330               galli   \N              Nanni
# Gamble                        545              gamble   \N               Fred
# Ganley                        307              ganley   \N             Howden
# Gardner                       380             gardner   \N              Frank
# Garrett                       595             garrett   \N              Billy
# Gartner                       189             gartner   \N                 Jo
# Gasly                         842               gasly  GAS             Pierre
# Gaze                          738                gaze   \N               Tony
# Gendebien                     482           gendebien   \N            Olivier
# Gené                           48                gene   \N               Marc
# George                        616              george   \N              Elmer
# Gerard                        619              gerard   \N                Bob
# Gerini                        583              gerini   \N             Gerino
# Gethin                        320              gethin   \N              Peter
# Ghinzani                      160            ghinzani   \N          Piercarlo
# Giacomelli                    152          giacomelli   \N              Bruno
# Gibson                        601              gibson   \N               Dick
# Ginther                       386             ginther   \N             Richie
# Giovinazzi                    841          giovinazzi  GIO            Antonio
# Giunti                        363              giunti   \N            Ignazio
# Glock                          10               glock  GLO               Timo
# Godia                         580               godia   \N               Paco
# Goethals                      600            goethals   \N          Christian
# Goldsmith                     510           goldsmith   \N               Paul
# González                      806      oscar_gonzalez   \N              Óscar
# González                      498            gonzalez   \N       José Froilán
# Gordini                       775             gordini   \N               Aldo
# Gould                         547               gould   \N             Horace
# Gounon                        111              gounon   \N          Jean-Marc
# Green                         770               green   \N              Cecil
# Greene                        465              greene   \N              Keith
# Gregory                       418             gregory   \N             Masten
# Griffith                      629            griffith   \N              Cliff
# Grignard                      783            grignard   \N            Georges
# Grim                          522                grim   \N              Bobby
# Grosjean                      154            grosjean  GRO             Romain
# Grouillard                    129          grouillard   \N            Olivier
# Gubby                         422               gubby   \N              Brian
# Guelfi                        603              guelfi   \N              André
# Guerra                        215              guerra   \N       Miguel Ángel
# Guerrero                      195            guerrero   \N            Roberto
# Gugelmin                      127            gugelmin   \N           Maurício
# Gurney                        364              gurney   \N                Dan
# Gutiérrez                     821           gutierrez  GUT            Esteban
# Gálvez                        695              galvez   \N              Oscar
# Hahne                         365               hahne   \N             Hubert
# Hailwood                      305            hailwood   \N               Mike
# Halford                       506             halford   \N              Bruce
# Hall                          440                hall   \N                Jim
# Hamilton                      708     duncan_hamilton   \N             Duncan
# Hamilton                        1            hamilton  HAM              Lewis
# Hampshire                     784           hampshire   \N              David
# Hanks                         611               hanks   \N                Sam
# Hansgen                       433             hansgen   \N               Walt
# Harris                        472              harris   \N               Mike
# Harrison                      787            harrison   \N               Cuth
# Hart                          391                hart   \N              Brian
# Hartley                       843     brendon_hartley  HAR            Brendon
# Hartley                       520             hartley   \N               Gene
# Haryanto                      837            haryanto  HAR                Rio
# Hasemi                        287              hasemi   \N           Masahiro
# Hattori                       144             hattori   \N              Naoki
# Hawkins                       406             hawkins   \N               Paul
# Hawthorn                      578            hawthorn   \N               Mike
# Heeks                         712               heeks   \N              Willi
# Heidfeld                        2            heidfeld  HEI               Nick
# Helfrich                      692            helfrich   \N               Theo
# Hellings                      772            hellings   \N               Mack
# Henton                        205              henton   \N              Brian
# Herbert                        65             herbert   \N             Johnny
# Herman                        538              herman   \N                 Al
# Herrmann                      478            herrmann   \N               Hans
# Hesnault                      183            hesnault   \N           François
# Heyer                         268               heyer   \N               Hans
# Hill                           71          damon_hill   \N              Damon
# Hill                          403           phil_hill   \N               Phil
# Hill                          289                hill   \N             Graham
# Hirt                          721                hirt   \N              Peter
# Hobbs                         322               hobbs   \N              David
# Hocking                       473             hocking   \N               Gary
# Hoffmann                      253            hoffmann   \N               Ingo
# Holland                       701             holland   \N               Bill
# Holmes                        797              holmes   \N             Jackie
# Homeier                       519             homeier   \N               Bill
# Hoshino                       273             hoshino   \N          Kazuyoshi
# Hoyt                          659                hoyt   \N              Jerry
# Hulme                         304               hulme   \N              Denny
# Hunt                          231                hunt   \N              James
# Hurtubise                     524           hurtubise   \N                Jim
# Hutchison                     366           hutchison   \N                Gus
# Häkkinen                       57            hakkinen   \N               Mika
# Hülkenberg                    807          hulkenberg  HUL               Nico
# Ickx                          235                ickx   \N              Jacky
# Ide                            34                 ide  IDE               Yuji
# Iglesias                      646            iglesias   \N              Jesús
# Inoue                          89               inoue   \N               Taki
# Ireland                       404             ireland   \N              Innes
# Irvine                         56              irvine   \N              Eddie
# Irwin                         388               irwin   \N              Chris
# Jabouille                     219           jabouille   \N        Jean-Pierre
# Jackson                       799             jackson   \N              Jimmy
# James                         779          john_james   \N               John
# James                         728               james   \N                Joe
# Jarier                        197              jarier   \N        Jean-Pierre
# Jean                          349                jean   \N                Max
# Johansson                     140           johansson   \N             Stefan
# Johnson                       513             johnson   \N              Eddie
# Johnson                       790      leslie_johnson   \N             Leslie
# Johnstone                     471           johnstone   \N              Bruce
# Jones                         178               jones   \N               Alan
# Jones                         393           tom_jones   \N                Tom
# Jover                         782               jover   \N               Juan
# Järvilehto                    109               lehto   \N              Jyrki
# Karch                         711               karch   \N             Oswald
# Karthikeyan                    39         karthikeyan  KAR             Narain
# Katayama                       79            katayama   \N               Ukyo
# Kavanagh                      582            kavanagh   \N                Ken
# Keegan                        211              keegan   \N             Rupert
# Keizan                        292              keizan   \N              Eddie
# Keller                        558              keller   \N                 Al
# Kelly                         776               kelly   \N                Joe
# Kennedy                       225             kennedy   \N               Dave
# Kessel                        271              kessel   \N              Loris
# Kessler                       584             kessler   \N              Bruce
# Kiesa                          53               kiesa   \N            Nicolas
# Kinnunen                      316            kinnunen   \N                Leo
# Kladis                        805              kladis   \N              Danny
# Klenk                         753               klenk   \N               Hans
# Klien                          32               klien  KLI          Christian
# Kling                         648               kling   \N               Karl
# Klodwig                       709             klodwig   \N              Ernst
# Kobayashi                     155           kobayashi  KOB              Kamui
# Koinigg                       324             koinigg   \N            Helmuth
# Kovalainen                      5          kovalainen  KOV             Heikki
# Kozarowitzky                  263        kozarowitzky   \N              Mikko
# Krause                        710              krause   \N             Rudolf
# Kubica                          9              kubica  KUB             Robert
# Kuhnke                        442              kuhnke   \N               Kurt
# Kvyat                         826               kvyat  KVY             Daniil
# La Caze                       602             la_caze   \N             Robert
# Laffite                       172             laffite   \N            Jacques
# Lagorce                       116             lagorce   \N             Franck
# Lammers                       136             lammers   \N                Jan
# Lamy                           83                lamy   \N              Pedro
# Landi                         622               landi   \N              Chico
# Lang                          691                lang   \N            Hermann
# Langes                        149              langes   \N            Claudio
# Larini                         78              larini   \N             Nicola
# Larrauri                      165            larrauri   \N              Oscar
# Larreta                       497             larreta   \N  Alberto Rodriguez
# Larrousse                     315           larrousse   \N             Gérard
# Larson                        564              larson   \N                Jud
# Latifi                        849              latifi  LAT           Nicholas
# Lauda                         182               lauda   \N               Niki
# Laurent                       736             laurent   \N              Roger
# Lavaggi                        86             lavaggi   \N           Giovanni
# Lawrence                      400            lawrence   \N              Chris
# Leclerc                       844             leclerc  LEC            Charles
# Leclère                       277             leclere   \N             Michel
# Lederle                       410             lederle   \N            Neville
# Lees                          209                lees   \N              Geoff
# Legat                         703               legat   \N             Arthur
# Leoni                         241               leoni   \N           Lamberto
# Leston                        610              leston   \N                Les
# Levegh                        773              levegh   \N             Pierre
# Levrett                       798             levrett   \N            Bayliss
# Lewis                         453               lewis   \N             Jackie
# Lewis-Evans                   590         lewis-evans   \N             Stuart
# Ligier                        389              ligier   \N                Guy
# Linden                        612              linden   \N               Andy
# Lippi                         444               lippi   \N            Roberto
# Liuzzi                         24              liuzzi  LIU         Vitantonio
# Lombardi                      275            lombardi   \N              Lella
# Londoño                       218             londono   \N            Ricardo
# Loof                          718                loof   \N              Ernst
# Lotterer                      827            lotterer  LOT              André
# Louveau                       765             louveau   \N              Henri
# Love                          340                love   \N               John
# Lovely                        353              lovely   \N               Pete
# Loyer                         671               loyer   \N              Roger
# Lucas                         668               lucas   \N               Jean
# Lucienbonnet                  552        lucienbonnet   \N               Jean
# Lunger                        257               hayje   \N                Boy
# Lunger                        239              lunger   \N              Brett
# MacDowel                      617            macdowel   \N               Mike
# MacKay-Fraser                 618       mackay-fraser   \N            Herbert
# Mackey                        769              mackey   \N               Bill
# Macklin                       651             macklin   \N              Lance
# Magee                         282               magee   \N             Damien
# Maggs                         408               maggs   \N               Tony
# Magill                        565              magill   \N               Mike
# Maglioli                      620            maglioli   \N            Umberto
# Magnussen                     825     kevin_magnussen  MAG              Kevin
# Magnussen                      76           magnussen  MAG                Jan
# Mairesse                      435            mairesse   \N              Willy
# Mairesse                      764        guy_mairesse   \N                Guy
# Maldonado                     813           maldonado  MAL             Pastor
# Mansell                        95             mansell   \N              Nigel
# Mantovani                     644           mantovani   \N             Sergio
# Mantz                         804               mantz   \N             Johnny
# Manzon                        626              manzon   \N             Robert
# Marimón                       670             marimon   \N             Onofre
# Marko                         337               marko   \N             Helmut
# Marques                        58             marques   \N              Tarso
# Marr                          665                marr   \N             Leslie
# Marsh                         459               marsh   \N               Tony
# Martin                        789              martin   \N             Eugène
# Martini                        94             martini   \N          Pierluigi
# Mass                          200                mass   \N             Jochen
# Massa                          13               massa  MAS             Felipe
# May                           480                 may   \N            Michael
# Mayer                         470               mayer   \N              Timmy
# Mazepin                       853             mazepin  MAZ             Nikita
# Mazet                         348               mazet   \N           François
# Mazzacane                      60           mazzacane   \N             Gastón
# McAlpine                      664            mcalpine   \N            Kenneth
# McCarthy                      135            mccarthy   \N              Perry
# McCoy                         679               mccoy   \N              Ernie
# McDowell                      732            mcdowell   \N             Johnny
# McGrath                       658             mcgrath   \N               Jack
# McGuire                       266             mcguire   \N              Brian
# McLaren                       360             mclaren   \N              Bruce
# McNish                         66              mcnish   \N              Allan
# McRae                         336               mcrae   \N             Graham
# McWithey                      535            mcwithey   \N                Jim
# Menditeguy                    496          menditeguy   \N             Carlos
# Merhi                         833               merhi  MER            Roberto
# Merzario                      232            merzario   \N             Arturo
# Mieres                        643              mieres   \N            Roberto
# Migault                       296             migault   \N           François
# Miles                         357               miles   \N               John
# Miles                         495           ken_miles   \N                Ken
# Milhoux                       639             milhoux   \N              André
# Miller                        733              miller   \N               Chet
# Mitter                        423              mitter   \N            Gerhard
# Modena                        131              modena   \N            Stefano
# Monarch                       452             monarch   \N             Thomas
# Montagny                       36            montagny  FMO             Franck
# Monteiro                       33            monteiro  TMO              Tiago
# Montermini                     85          montermini   \N             Andrea
# Monteverdi                    488          monteverdi   \N              Peter
# Montgomerie-Charrington       739         charrington   \N              Robin
# Morbidelli                     81          morbidelli   \N             Gianni
# Moreno                         90              moreno   \N            Roberto
# Morgan                        301              morgan   \N               Dave
# Moser                         351               moser   \N             Silvio
# Moss                          570           bill_moss   \N               Bill
# Moss                          475                moss   \N           Stirling
# Munaron                       500             munaron   \N               Gino
# Murray                        747              murray   \N              David
# Musso                         577               musso   \N              Luigi
# Nakajima                        6            nakajima  NAK             Kazuki
# Nakajima                      138     satoru_nakajima   \N             Satoru
# Nakano                         75              nakano   \N             Shinji
# Nalon                         699               nalon   \N               Duke
# Nannini                       145             nannini   \N         Alessandro
# Naspetti                      125            naspetti   \N           Emanuele
# Nasr                          831                nasr  NAS             Felipe
# Natili                        487              natili   \N            Massimo
# Naylor                        484              naylor   \N              Brian
# Nazaruk                       673             nazaruk   \N               Mike
# Needell                       227             needell   \N               Tiff
# Nelleman                      281            nelleman   \N                Jac
# Nicholson                     300           nicholson   \N               John
# Niday                         655               niday   \N                Cal
# Niedermayr                    752          niedermayr   \N             Helmut
# Niemann                       412             niemann   \N            Brausch
# Nilsson                       255             nilsson   \N             Gunnar
# Noda                          115                noda   \N             Hideki
# Norris                        846              norris  NOR              Lando
# Nuckey                        690              nuckey   \N             Rodney
# Nève                          258                neve   \N            Patrick
# O'Brien                       737              obrien   \N             Robert
# O'Connor                      597              connor   \N                Pat
# Ocon                          839                ocon  OCO            Esteban
# Oliver                        262              oliver   \N             Jackie
# Ongais                        240              ongais   \N              Danny
# Owen                          546                owen   \N             Arthur
# Pablo Montoya                  31             montoya  MON               Juan
# Pace                          250                pace   \N             Carlos
# Pagani                        800              pagani   \N              Nello
# Paletti                       204             paletti   \N           Riccardo
# Palm                          297                palm   \N            Torsten
# Palmer                        156              palmer   \N           Jonathan
# Palmer                        835       jolyon_palmer  PAL             Jolyon
# Panis                          44               panis   \N            Olivier
# Pantano                        45             pantano   \N            Giorgio
# Papis                          97               papis   \N       Massimiliano
# Parkes                        387              parkes   \N               Mike
# Parnell                       441             parnell   \N                Tim
# Parnell                       686         reg_parnell   \N                Reg
# Parsons                       593             parsons   \N            Johnnie
# Patrese                       119             patrese   \N           Riccardo
# Pease                         371               pease   \N                 Al
# Penske                        468              penske   \N              Roger
# Perdisa                       607             perdisa   \N             Cesare
# Perkins                       256             perkins   \N              Larry
# Pescarolo                     280           pescarolo   \N              Henri
# Pesenti-Rossi                 284       pesenti_rossi   \N         Alessandro
# Peters                        757              peters   \N              Josef
# Peterson                      238            peterson   \N             Ronnie
# Petrov                        808              petrov  PET             Vitaly
# Pic                           819                 pic  PIC            Charles
# Picard                        604              picard   \N           François
# Pieterse                      413            pieterse   \N              Ernie
# Pietsch                       756             pietsch   \N               Paul
# Pilette                       269             pilette   \N              Teddy
# Pilette                       429       andre_pilette   \N              André
# Piotti                        586              piotti   \N              Luigi
# Piper                         542               piper   \N              David
# Piquet                        137              piquet   \N             Nelson
# Piquet Jr.                     12           piquet_jr  PIQ             Nelson
# Pirocchi                      489            pirocchi   \N             Renato
# Pironi                        202              pironi   \N             Didier
# Pirro                         139               pirro   \N           Emanuele
# Pizzonia                       42            pizzonia  PIZ            Antônio
# Pián                          792                pian   \N            Alfredo
# Pollet                        650              pollet   \N            Jacques
# Pon                           457                 pon   \N                Ben
# ...
# Mieres                           Argentine
# Migault                             French
# Miles                              British
# Miles                              British
# Milhoux                            Belgian
# Miller                            American
# Mitter                              German
# Modena                             Italian
# Monarch                           American
# Montagny                            French
# Monteiro                        Portuguese
# Montermini                         Italian
# Monteverdi                           Swiss
# Montgomerie-Charrington            British
# Morbidelli                         Italian
# Moreno                           Brazilian
# Morgan                             British
# Moser                                Swiss
# Moss                               British
# Moss                               British
# Munaron                            Italian
# Murray                             British
# Musso                              Italian
# Nakajima                          Japanese
# Nakajima                          Japanese
# Nakano                            Japanese
# Nalon                             American
# Nannini                            Italian
# Naspetti                           Italian
# Nasr                             Brazilian
# Natili                             Italian
# Naylor                             British
# Nazaruk                           American
# Needell                            British
# Nelleman                            Danish
# Nicholson                    New Zealander
# Niday                             American
# Niedermayr                          German
# Niemann                      South African
# Nilsson                            Swedish
# Noda                              Japanese
# Norris                             British
# Nuckey                             British
# Nève                               Belgian
# O'Brien                           American
# O'Connor                          American
# Ocon                                French
# Oliver                             British
# Ongais                            American
# Owen                               British
# Pablo Montoya                    Colombian
# Pace                             Brazilian
# Pagani                             Italian
# Paletti                            Italian
# Palm                               Swedish
# Palmer                             British
# Palmer                             British
# Panis                               French
# Pantano                            Italian
# Papis                              Italian
# Parkes                             British
# Parnell                            British
# Parnell                            British
# Parsons                           American
# Patrese                            Italian
# Pease                             Canadian
# Penske                            American
# Perdisa                            Italian
# Perkins                         Australian
# Pescarolo                           French
# Pesenti-Rossi                      Italian
# Peters                              German
# Peterson                           Swedish
# Petrov                             Russian
# Pic                                 French
# Picard                              French
# Pieterse                     South African
# Pietsch                             German
# Pilette                            Belgian
# Pilette                            Belgian
# Piotti                             Italian
# Piper                              British
# Piquet                           Brazilian
# Piquet Jr.                       Brazilian
# Pirocchi                           Italian
# Pironi                              French
# Pirro                              Italian
# Pizzonia                         Brazilian
# Pián                             Argentine
# Pollet                              French
# Pon                                  Dutch
# Poore                              British
# Posey                             American
# Pozzi                               French
# Pretorius                    South African
# Prinoth                            Italian
# Prophet                            British
# Prost                               French
# Pryce                              British
# Purley                             British
# Puzey                            Rhodesian
# Pérez                              Mexican
# Pérez-Sala                         Spanish
# Quester                           Austrian
# Raby                               British
# Rahal                             American
# Raphanel                            French
# Rathmann                          American
# Rathmann                          American
# Ratzenberger                      Austrian
# Rebaque                            Mexican
# Redman                             British
# Reece                             American
# Reed                         South African
# Rees                               British
# Regazzoni                            Swiss
# Reutemann                        Argentine
# Reventlow                         American
# Revson                            American
# Rhodes                             British
# Ribeiro                          Brazilian
# Ricciardo                       Australian
# Richardson                         British
# Riess                               German
# Rigsby                            American
# Rindt                             Austrian
# Riseley-Prichard                   British
# Robarts                            British
# Rodríguez                          Mexican
# Rodríguez                          Mexican
# Rol                                Italian
# Rollinson                          British
# Rolt                               British
# Roos                               Swedish
# Rosberg                             German
# Rosberg                            Finnish
# Rose                              American
# Rosier                              French
# Rosset                           Brazilian
# Rossi                             American
# Rothengatter                         Dutch
# Ruby                              American
# Russell                            British
# Russo                             American
# Russo                             American
# Russo                              Italian
# Ruttman                           American
# Ryan                              Canadian
# Räikkönen                          Finnish
# Sachs                             American
# Said                              American
# Sainz                              Spanish
# Salazar                            Chilean
# Salo                               Finnish
# Salvadori                          British
# Sanesi                             Italian
# Sarrazin                            French
# Sato                              Japanese
# Scarborough                       American
# Scarfiotti                         Italian
# Scarlatti                          Italian
# Scheckter                    South African
# Scheckter                    South African
# Schell                            American
# Schenken                        Australian
# Scherrer                             Swiss
# Schiattarella                      Italian
# Schiller                             Swiss
# Schindler                         American
# Schlesser                           French
# Schlesser                           French
# Schneider                           German
# Schoeller                            Swiss
# Schroeder                          British
# Schumacher                          German
# Schumacher                          German
# Schumacher                          German
# Schuppan                        Australian
# Scott                             American
# Scott Brown                        British
# Scotti                             Italian
# Seidel                              German
# Seiffert                            German
# Senna                            Brazilian
# Senna                            Brazilian
# Serafini                           Italian
# Serra                            Brazilian
# Serrurier                    South African
# Servoz-Gavin                        French
# Settember                         American
# Sharp                             American
# Shawe Taylor                       British
# Shelby                            American
# Shelly                       New Zealander
# Siffert                              Swiss
# Simon                               French
# Sirotkin                           Russian
# Slotemaker                           Dutch
# Solana                             Mexican
# Soler-Roig                         Spanish
# Sommer                              French
# Sospiri                            Italian
# South                              British
# Sparken                             French
# Speed                             American
# Spence                             British
# Stacey                             British
# Starrabba                          Italian
# Stevens                            British
# Stevenson                         American
# Stewart                            British
# Stewart                            British
# Stewart                            British
# Stohr                              Italian
# Stommelen                           German
# Streiff                             French
# Stroll                            Canadian
# Stuck                               German
# Stuppacher                        Austrian
# Sullivan                          American
# Surer                                Swiss
# Surtees                            British
# Sutcliffe                          British
# Sutil                               German
# Sutton                            American
# Suzuki                            Japanese
# Suzuki                            Japanese
# Swaters                           American
# Sweikert                          American
# Takagi                            Japanese
# Takahara                          Japanese
# Takahashi                         Japanese
# Tambay                              French
# Taramazzo                          Italian
# Tarquini                           Italian
# Taruffi                            Italian
# Taylor                             British
# Taylor                             British
# Taylor                             British
# Taylor                             British
# Taylor                             British
# Teague                            American
# Templeman                         American
# Testut                          Monegasque
# Thackwell                    New Zealander
# Thiele                    American-Italian
# Thompson                           British
# Thomson                           American
# Thorne                             British
# Tingelstad                        American
# Tingle                           Rhodesian
# Titterington                       British
# Tolan                             American
# Trimmer                            British
# Trintignant                         French
# Trulli                             Italian
# Tsunoda                           Japanese
# Tuero                            Argentine
# Tunmer                       South African
# Turner                            American
# Ulmen                               German
# Unser                             American
# Unser                             American
# Uria                             Uruguayan
# Vaccarella                         Italian
# Vandoorne                          Belgian
# Veith                             American
# Vergne                              French
# Verstappen                           Dutch
# Verstappen                           Dutch
# Vettel                              German
# Villeneuve                        Canadian
# Villeneuve                        Canadian
# Villeneuve Sr.                    Canadian
# Villoresi                          Italian
# Volonterio                           Swiss
# Vonlanthen                           Swiss
# Vukovich                          American
# Wacker                            American
# Walker                          Australian
# Walker                             British
# Wallard                           American
# Walter                               Swiss
# Ward                              American
# Warwick                            British
# Watson                             British
# Webb                              American
# Webber                          Australian
# Wehrlein                            German
# Weidler                             German
# Weiler                            American
# Wendlinger                        Austrian
# Westbury                           British
# Weyant                            American
# Wharton                            British
# Whiteaway                          British
# Whitehead                          British
# Whitehead                          British
# Whitehouse                         British
# Widdows                            British
# Wietzes                           Canadian
# Wilds                              British
# Williams                           British
# Williamson                         British
# Wilson                             British
# Wilson                            American
# Wilson                       South African
# Wilson                             British
# Winkelhock                          German
# Winkelhock                          German
# Winkelhock                          German
# Wisell                             Swedish
# Wunderink                            Dutch
# Wurz                              Austrian
# Yamamoto                          Japanese
# Yoong                            Malaysian
# Zanardi                            Italian
# Zapico                             Spanish
# Zhou                               Chinese
# Zonta                            Brazilian
# Zorzi                              Italian
# Zunino                           Argentine
# d'Ambrosio                         Belgian
# d'Orey                           Brazilian
# da Matta                         Brazilian
# da Silva Ramos                   Brazilian
# de Adamich                         Italian
# de Angelis                         Italian
# de Beaufort                          Dutch
# de Cesaris                         Italian
# de Changy                          Belgian
# de Dryver                          Belgian
# de Filippis                        Italian
# de Graffenried                       Swiss
# de Klerk                     South African
# de Portago                         Spanish
# de Riu                             Italian
# de Terra                             Swiss
# de Tomaso                Argentine-Italian
# de Tornaco                         Belgian
# de Villota                         Spanish
# de Vos                               Dutch
# de la Rosa                         Spanish
# di Grassi                        Brazilian
# di Resta                           British
# van Lennep                           Dutch
# van Rooyen                   South African
# van de Poele                       Belgian
# van der Garde                        Dutch
# van der Lof                          Dutch
# van der Vyver                South African
# von Opel                   Liechtensteiner
# von Stuck                           German
# von Trips                           German
# Étancelin                           French

# %%
#Driver Standings dataset
driver_standings_csv = "Resources/Data/archive/driver_standings.csv"
driver_standings = pd.read_csv(driver_standings_csv)
standings_rename = driver_standings.rename(columns={"points":"StandingsPoints"})

# %% [markdown]
# # Merge multiple datasets together

# %%
#Merging the results and races datasets
merge1 = pd.merge(results, races, how="inner", on="raceId")

# %%
#Merging the drivers dataset with the results and races datasets.
merge2 = pd.merge(merge1, drivers, how="inner", on="driverId")

# %%
#Finally, merging the driver standings to the previously merged datasets
merge3 = pd.merge(merge2, driver_standings, how="inner", on=("raceId","driverId"))

#Rename final dataframe columns for ease of understanding
final = merge3.rename(columns={"number":"CarNumber","positionOrder":"FinalRank","round":"SeasonRound",})

# %% [markdown]
# # Group values by year to determine the highest amount of points per season

# %%
#Grouping the dataframe using the year and driver Ids categories. 
# While grouping, I'm also selecting the highest amount of points for each driver, per season.
year_group = final.groupby(by=["year","driverId"], sort=False)["points"].max()
points_df = year_group.to_frame()

# %% [markdown]
# # Reduce drivers dataframe to relevant information

# %%
drivers_limited = drivers_df[["driverId", "driverRef"]]

# %% [markdown]
# # Pull out points for each year & merge with limited drivers dataframe

# %% [markdown]
# ### 2000

# %%
#Pull out points for each year. 
points_2000 = points_df.loc[2000].sort_values(by="points", ascending=False)

#Merge dataframes
driver00_merge = pd.merge(points_2000, drivers_limited, how="inner", on=("driverId"))

driver00_merge["year"] = 2000

# %% [markdown]
# ### 2001

# %%
#Pull out points for each year. 
points_2001 = points_df.loc[2001].sort_values(by="points", ascending=False)

#Merge dataframes
driver01_merge = pd.merge(points_2001, drivers_limited, how="inner", on=("driverId"))

driver01_merge["year"] = 2001

# %% [markdown]
# ### 2002

# %%
#Pull out points for each year. 
points_2002 = points_df.loc[2002].sort_values(by="points", ascending=False)

#Merge dataframes
driver02_merge = pd.merge(points_2002, drivers_limited, how="inner", on=("driverId"))

driver02_merge["year"] = 2002

# %% [markdown]
# ### 2003

# %%
#Pull out points for each year. 
points_2003 = points_df.loc[2003].sort_values(by="points", ascending=False)

#Merge dataframes
driver03_merge = pd.merge(points_2003, drivers_limited, how="inner", on=("driverId"))

driver03_merge["year"] = 2003

# %% [markdown]
# ### 2004

# %%
#Pull out points for each year. 
points_2004 = points_df.loc[2004].sort_values(by="points", ascending=False)

#Merge dataframes
driver04_merge = pd.merge(points_2004, drivers_limited, how="inner", on=("driverId"))

driver04_merge["year"] = 2004

# %% [markdown]
# ### 2005

# %%
#Pull out points for each year. 
points_2005 = points_df.loc[2005].sort_values(by="points", ascending=False)

#Merge dataframes
driver05_merge = pd.merge(points_2005, drivers_limited, how="inner", on=("driverId"))

driver05_merge["year"] = 2005

# %% [markdown]
# ### 2006

# %%
#Pull out points for each year. 
points_2006 = points_df.loc[2006].sort_values(by="points", ascending=False)

#Merge dataframes
driver06_merge = pd.merge(points_2006, drivers_limited, how="inner", on=("driverId"))

driver06_merge["year"] = 2006

# %% [markdown]
# ### 2007

# %%
#Pull out points for each year. 
points_2007 = points_df.loc[2007].sort_values(by="points", ascending=False)

#Merge dataframes
driver07_merge = pd.merge(points_2007, drivers_limited, how="inner", on=("driverId"))

driver07_merge["year"] = 2007

# %% [markdown]
# ### 2008

# %%
#Pull out points for each year. 
points_2008 = points_df.loc[2008].sort_values(by="points", ascending=False)

#Merge dataframes
driver08_merge = pd.merge(points_2008, drivers_limited, how="inner", on=("driverId"))

driver08_merge["year"] = 2008

# %% [markdown]
# ### 2009

# %%
#Pull out points for each year. 
points_2009 = points_df.loc[2009].sort_values(by="points", ascending=False)

#Merge dataframes
driver09_merge = pd.merge(points_2009, drivers_limited, how="inner", on=("driverId"))

driver09_merge["year"] = 2009

# %% [markdown]
# ### 2010

# %%
#Pull out points for each year. 
points_2010 = points_df.loc[2010].sort_values(by="points", ascending=False)

#Merge dataframes
driver10_merge = pd.merge(points_2010, drivers_limited, how="inner", on=("driverId"))

driver10_merge["year"] = 2010

# %% [markdown]
# ### 2011

# %%
#Pull out points for each year. 
points_2011 = points_df.loc[2011].sort_values(by="points", ascending=False)

#Merge dataframes
driver11_merge = pd.merge(points_2011, drivers_limited, how="inner", on=("driverId"))

driver11_merge["year"] = 2011

# %% [markdown]
# ### 2012

# %%
#Pull out points for each year. 
points_2012 = points_df.loc[2012].sort_values(by="points", ascending=False)

#Merge dataframes
driver12_merge = pd.merge(points_2012, drivers_limited, how="inner", on=("driverId"))

driver12_merge["year"] = 2012

# %% [markdown]
# ### 2013

# %%
#Pull out points for each year. 
points_2013 = points_df.loc[2013].sort_values(by="points", ascending=False)

#Merge dataframes
driver13_merge = pd.merge(points_2013, drivers_limited, how="inner", on=("driverId"))

driver13_merge["year"] = 2013

# %% [markdown]
# ### 2014

# %%
#Pull out points for each year. 
points_2014 = points_df.loc[2014].sort_values(by="points", ascending=False)

#Merge dataframes
driver14_merge = pd.merge(points_2014, drivers_limited, how="inner", on=("driverId"))

driver14_merge["year"] = 2014

# %% [markdown]
# ### 2015

# %%
#Pull out points for each year. 
points_2015 = points_df.loc[2015].sort_values(by="points", ascending=False)

#Merge dataframes
driver15_merge = pd.merge(points_2015, drivers_limited, how="inner", on=("driverId"))

driver15_merge["year"] = 2015

# %% [markdown]
# ### 2016

# %%
#Pull out points for each year. 
points_2016 = points_df.loc[2016].sort_values(by="points", ascending=False)

#Merge dataframes
driver16_merge = pd.merge(points_2016, drivers_limited, how="inner", on=("driverId"))

# %% [markdown]
# ### 2017

# %%
#Pull out points for each year. 
points_2017 = points_df.loc[2017].sort_values(by="points", ascending=False)

#Merge dataframes
driver17_merge = pd.merge(points_2017, drivers_limited, how="inner", on=("driverId"))

driver17_merge["year"] = 2017

# %% [markdown]
# ### 2018

# %%
#Pull out points for each year. 
points_2018 = points_df.loc[2018].sort_values(by="points", ascending=False)

#Merge dataframes
driver18_merge = pd.merge(points_2018, drivers_limited, how="inner", on=("driverId"))

driver18_merge["year"] = 2018

# %% [markdown]
# ### 2019

# %%
#Pull out points for each year. 
points_2019 = points_df.loc[2019].sort_values(by="points", ascending=False)

#Merge dataframes
driver19_merge = pd.merge(points_2019, drivers_limited, how="inner", on=("driverId"))

driver19_merge["year"] = 2019

# %% [markdown]
# ### 2020

# %%
#Pull out points for each year. 
points_2020 = points_df.loc[2020].sort_values(by="points", ascending=False)

#Merge dataframes
driver20_merge = pd.merge(points_2020, drivers_limited, how="inner", on=("driverId"))

driver20_merge["year"] = 2020

# %% [markdown]
# ### 2021

# %%
#Pull out points for each year. 
points_2021 = points_df.loc[2021].sort_values(by="points", ascending=False)

#Merge dataframes
driver21_merge = pd.merge(points_2021, drivers_limited, how="inner", on=("driverId"))

driver21_merge["year"] = 2021

# %% [markdown]
# # Concatenate all merged datasets

# %%
drivercon = [driver00_merge,
                 driver01_merge,
                 driver02_merge,
                 driver03_merge,
                 driver04_merge,
                 driver05_merge,
                 driver06_merge, 
                 driver07_merge,
                 driver08_merge, 
                 driver09_merge, 
                 driver10_merge, 
                 driver11_merge, 
                 driver12_merge, 
                 driver13_merge, 
                 driver14_merge, 
                 driver15_merge, 
                 driver16_merge, 
                 driver17_merge, 
                 driver18_merge, 
                 driver19_merge, 
                 driver20_merge, 
                 driver21_merge]

driver_concat = pd.concat(drivercon)

#Remove trailing decimal
driver_concat["year"] = driver_concat["year"].astype(str).str.replace('.0', '', regex=False)

# %% [markdown]
# # Select championship winners from 2000 - 2021

# %%
winners = driver_concat.loc[0]

winners
# Out:
#    driverId  points           driverRef  year
# 0        30   108.0  michael_schumacher  2000
# 0        30   123.0  michael_schumacher  2001
# 0        30   144.0  michael_schumacher  2002
# 0        30    93.0  michael_schumacher  2003
# 0        30   148.0  michael_schumacher  2004
# 0         4   133.0              alonso  2005
# 0         4   134.0              alonso  2006
# 0         8   110.0           raikkonen  2007
# 0         1    98.0            hamilton  2008
# 0        18    95.0              button  2009
# 0        20   256.0              vettel  2010
# 0        20   392.0              vettel  2011
# 0        20   281.0              vettel  2012
# 0        20   397.0              vettel  2013
# 0         1   384.0            hamilton  2014
# 0         1   381.0            hamilton  2015
# 0         3   385.0             rosberg   nan
# 0         1   363.0            hamilton  2017
# 0         1   408.0            hamilton  2018
# 0         1   413.0            hamilton  2019
# 0         1   347.0            hamilton  2020
# 0       830   395.5      max_verstappen  2021

# %% [markdown]
# # Create trivia questions

# %% [markdown]
# year = winners["year"]
#
# quizQuestions = [
# f"Who won the championship in {yearAns}?"
# for year in yearAns]
#
# def quizQuestions(year):
#     question = f"Who won the championship in {year}?"
#     print(question)
#
# for year in yearAns:
#     print(f"Who won the championship in {yearAns}?")

# %% [markdown]
# class Question:
#     def __init__(self, questionText, variable, answer, multipleChoiceOptions=None, alternateAnswers=None):
#         self.questionText = questionText
#         self.variable = variable
#         self.answer = answer
#         self.multipleChoiceOptions = multipleChoiceOptions
#         self.alternateAnswers = alternateAnswers
#
#     def __repr__(self):
#         return '{'+ self.questionText +', '+self.variable+' '+ self.answer +', '+ str(self.multipleChoiceOptions) +', '+ str(self.alternateAnswers) +'}'

# %% [markdown]
# question_text = "Who won the F1 championship in\n"
# print ("[question_text] (%s)?" % '1, 2, 3')

# %% [markdown]
# question_text = "Who won the F1 championship in %s ?\n"
#
# variable = 1950, 1960, 1970
#
# answer = "tom", "jerry", "paul"
#
# Question(question_text, variable, answer)

# %% [markdown]
# string = ("Who won the F1 championship in %s ?\n")
#
# for i in range(2000,2022):
#     questionText = string % i
#     userInput = input()
#     if (userInput.lower() == question.answer.lower()):
#         print("That is correct!")
#     elif (question.alternateAnswers != None and userInput.lower() in question.alternateAnswers):
#         print("That is correct!")
#     else:
#         print(f"Sorry, the correct answer is {question.answer}.")

# %% [markdown]
# quizQuestions = [
#     #...
#     Question("Question 5. What hemisphere is Japan located in", "Northern Hemisphere", [], ["north", "northern"]),
# ]

# %% [markdown]
# for question in quizQuestions:
#     print(f"{question.questionText}?")
#     userInput = input()
#     if (userInput.lower() == question.answer.lower()):
#         print("That is correct!")
#     elif (question.alternateAnswers != None and userInput.lower() in question.alternateAnswers):
#         print("That is correct!")
#     else:
#         print(f"Sorry, the correct answer is {question.answer}.")

# %% [markdown]
# user_play = "y"
#
# while user_play == "y":
#     for x in range(2, 7):
#
#         print(x)
#
#     user_play = input("Continue the chain: (y)es or (n)o? ")
